# %% [markdown]
# # Gene Ontology Analysis
#
# **Goal: ** as a way of evaluating the network, look for function enrichment in TF targets.

# %% [markdown]
# ## Read in network, and gene IDs

# %%
import pandas as pd

gene_toID = {}
ID_toGene = {}

with open('./gene_name_to_gene_id_TCGA.txt', 'rb') as handle:
    for line in handle:
        line = line.strip().split('|')
        if line[0] != '?':
            gene_toID[line[0]] = line[1]
            ID_toGene[line[1]] = line[0]
            
network_file = 'TCGA_BBSR1.1_combinedPriors_TfsPriors.tsv'
network = pd.read_csv(network_file, sep = '\t')
#network = network.loc[network['bootstraps'].abs() >= 15,:]
network = network.loc[network['bootstraps'].abs() >= 20,:]

# %% [markdown]
# ## Download and load gene ontology database

# %%
# Get http://geneontology.org/ontology/go-basic.obo
from goatools.base import download_go_basic_obo
obo_fname = download_go_basic_obo()

# Get ftp://ftp.ncbi.nlm.nih.gov/gene/DATA/gene2go.gz
from goatools.base import download_ncbi_associations
gene2go = download_ncbi_associations()

from goatools.obo_parser import GODag
obodag = GODag('go-basic.obo')

from __future__ import print_function
from goatools.associations import read_ncbi_gene2go
from goatools.go_enrichment import GOEnrichmentStudy

geneid2gos_human = read_ncbi_gene2go('gene2go', taxids=[9606])
print('{N:,} annotated human genes'.format(N=len(geneid2gos_human)))
# Out:
#   EXISTS: go-basic.obo
#   EXISTS: gene2go
# load obo file go-basic.obo
# go-basic.obo: fmt(1.2) rel(2017-03-31) 48,532 GO Terms
# 18,860 annotated human genes

# %% [markdown]
# ## For each group of TF targets, find enriched GO terms

# %%
GOterm_dict = {}

for regulator in network['regulator'].unique():
    genes = list(set(network['target'].tolist() + network['regulator'].tolist()))
    genes = [int(gene_toID[gene]) for gene in genes]
    targets = network.loc[network['regulator'] == regulator, 'target']
    targets = [int(gene_toID[target]) for target in targets]

    goeaobj = GOEnrichmentStudy(
            genes, # List of mouse protein-coding genes
            geneid2gos_human, # geneid/GO associations
            obodag, # Ontologies
            propagate_counts = False,
            alpha = 0.05, # significance cut-off
            methods = ['fdr_bh']) # multipletest correction method

    goea_results_all = goeaobj.run_study(targets)
    goea_results_sig = [r for r in goea_results_all if r.p_fdr_bh < 0.05]
    
    GOterm_df = []
    for GOterm in goea_results_sig:
        line = (regulator, GOterm.GO, GOterm.NS, GOterm.name, GOterm.p_fdr_bh, ','.join([ID_toGene[str(id)] for id in list(GOterm.study_items)]))
        GOterm_df.append(line)
    if len(GOterm_df) > 0:
        GOterm_df = pd.DataFrame(GOterm_df, columns = ['regulator', 'GO', 'NS', 'name', 'FDR', 'genes'])
        GOterm_dict[regulator] = GOterm_df.sort_values('FDR')
# Out:
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     52 out of     53 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   528 GO terms are associated with 52 of 53 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     14 out of     15 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   150 GO terms are associated with 14 of 15 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     19 out of     19 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   306 GO terms are associated with 19 of 19 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     42 out of     44 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   439 GO terms are associated with 42 of 44 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     28 out of     28 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   438 GO terms are associated with 28 of 28 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     11 out of     11 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   55 GO terms are associated with 11 of 11 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#      1 out of      1 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   5 GO terms are associated with 1 of 1 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#      9 out of      9 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   153 GO terms are associated with 9 of 9 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#      5 out of      5 study items found in association
# Running multitest correction: statsmodels fdr_bh
#
study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#    100 out of    101 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   1,001 GO terms are associated with 100 of 101 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     33 out of     33 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   531 GO terms are associated with 33 of 33 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#      3 out of      3 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   72 GO terms are associated with 3 of 3 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#      1 out of      1 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   16 GO terms are associated with 1 of 1 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     27 out of     27 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   361 GO terms are associated with 27 of 27 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     50 out of     50 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   446 GO terms are associated with 50 of 50 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     37 out of     37 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   357 GO terms are associated with 37 of 37 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#    105 out of    107 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   686 GO terms are associated with 105 of 107 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#    699 out of    716 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   3,347 GO terms are associated with 699 of 716 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#      4 out of      4 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   52 GO terms are associated with 4 of 4 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     14 out of     14 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   148 GO terms are associated with 14 of 14 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     16 out of     16 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   255 GO terms are associated with 16 of 16 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#      1 out of      1 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   5 GO terms are associated with 1 of 1 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#      9 out of      9 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   80 GO terms are associated with 9 of 9 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     14 out of     14 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   146 GO terms are associated with 14 of 14 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     35 out of     37 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   282 GO terms are associated with 35 of 37 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#      1 out of      1 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   71 GO terms are associated with 1 of 1 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items
#  9,949 out of 10,199 population items found in association
# Calculating uncorrected p-values using fisher
#     10 out of     10 study items found in association
# Running multitest correction: statsmodels fdr_bh
#   287 GO terms are associated with 10 of 10 study items
#   14,797 GO terms are associated with 9,949 of 10,199 population items

# %% [markdown]
# ## Find Regulators involved in Cell Cycle

# %%
GOterm_df = pd.concat(GOterm_dict.values())
GOterm_df = GOterm_df.loc[GOterm_df['NS'] == 'BP',:]
GOterm_df = GOterm_df.loc[GOterm_df['FDR'] <= 0.01,:]
regulators = [list(set([row['regulator'] for idx, row in GOterm_df.iterrows() if 'cell cycle' in row['name']])),
              list(set([row['regulator'] for idx, row in GOterm_df.iterrows() if 'mitot' in row['name']]))]
regulators = sum(regulators, [])

cell_cycle_df = GOterm_df.loc[GOterm_df['regulator'].isin(regulators),:]
remove = ['GO:0061418', 'GO:0038095', 'GO:0000209', 'GO:0042776', 'GO:0031146', 
          'GO:0070125', 'GO:0006521', 'GO:0070126', 'GO:0038061', 'GO:0060071', 
          'GO:0031146', 'GO:0002479', 'GO:0061418', 'GO:0016446', 'GO:0016447', 
          'GO:0072711', 'GO:0016925', 'GO:0042787', 'GO:0006521', 'GO:0061418', 
          'GO:0051437', 'GO:0038061', 'GO:0031146', 'GO:0002479', 'GO:0090263', 
          'GO:0090090', 'GO:0060071', 'GO:0043488', 'GO:0002223', 'GO:0048704', 
          'GO:0038095', 'GO:0033209', 'GO:0000165', 'GO:0009952', 'GO:0050852', 
          'GO:0043161', 'GO:0070126', 'GO:0070125', 'GO:0000209'] # apopt'GO:0008630'
cell_cycle_df = cell_cycle_df.loc[~cell_cycle_df['GO'].isin(remove)]

regulators = cell_cycle_df['regulator'].unique()
targets = list(set(sum([genes.split(',') for genes in cell_cycle_df['genes']], [])))
#df = network.loc[network['regulator'].isin(regulators) & network['target'].isin(targets),:]
df = network.loc[network['regulator'].isin(regulators),:]
df.loc[:,'bootstraps'] = df.loc[:,'bootstraps'].astype(str)
df.to_csv('cell_cycle_network.tsv', sep = '\t', index = False, encoding = 'utf-8')
# Out:
# /Users/dayanne/miniconda2/lib/python2.7/site-packages/pandas/core/indexing.py:477: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
cell_cycle_df.sort_values('FDR')['regulator'].unique()
# Out:
# array(['E2F1', 'E2F5', 'E2F4', 'ARX', 'UHRF1', 'E2F3', 'MAFK', 'FLI1'], dtype=object)

# %%
import sys
if ".." not in sys.path:
    sys.path.append("..")
    
from jp_gene_viz import dNetwork
from jp_gene_viz import multiple_network

dNetwork.load_javascript_support()

# %%
network_file = 'cell_cycle_network.tsv'
N = dNetwork.display_network(network_file, show = False, size_limit = 1000)
N.threshhold_slider.value = 19
N.connected_only_click(None)
N.font_size_slider.value = 0
N.tf_font_size_slider.value = 18
N.expand_click(None)
#N.layout_dropdown.value = 'fruchterman_reingold'
N.layout_dropdown.value = 'kamada_kawai'
N.labels_button.value = True
N.layout_click(None)
N.title_html.value = 'cell cycle'
N.show()
# Out:
# ('Reading network', 'cell_cycle_network.tsv')
# ('Loading saved layout', 'cell_cycle_network.tsv.layout.json')
# Omitting edges, using canvas, and fast layout default because the network is large

# %% [markdown]
# ## Find Regulators involved in Communication with Immune System

# %%
GOterm_df = pd.concat(GOterm_dict.values())
GOterm_df = pd.concat(GOterm_dict.values())
GOterm_df = GOterm_df.loc[GOterm_df['NS'] == 'BP',:]
GOterm_df = GOterm_df.loc[GOterm_df['FDR'] <= 0.01,:]

GOterms = sum([[name for name in GOterm_df['name'] if 'chemotaxis' in name], 
              [name for name in GOterm_df['name'] if 'MHC class I' in name],
              [name for name in GOterm_df['name'] if 'interferon' in name]], [])

#GOterms = sum([[name for name in GOterm_df['name'] if 'interferon' in name]], [])

immune_cell_df = GOterm_df.loc[GOterm_df['name'].isin(GOterms),:]

regulators = immune_cell_df['regulator'][~immune_cell_df['regulator'].isin(['E2F1', 'E2F5'])].unique() # checked manually, not the main enriched functions
targets = list(set(sum([genes.split(',') for genes in immune_cell_df['genes']], [])))
#df = network.loc[network['regulator'].isin(regulators) & network['target'].isin(targets),:]
df = network.loc[network['regulator'].isin(regulators),:]
df.loc[:,'bootstraps'] = df['bootstraps'].astype(str)
df.to_csv('immune_cell.tsv', sep = '\t', index = False, encoding = 'utf-8')

# %%
immune_cell_df.sort_values('FDR')['regulator'].unique()
# Out:
# array(['HIVEP2', 'RFXANK', 'RFXAP', 'IRF1', 'STAT2', 'STAT1', 'IRF9',
#        'IRF4', 'IRF7', 'IRF2', 'IRF8', 'NFKB1', 'SPI1', 'DLX1', 'STAT4',
#        'PRDM1', 'TRERF1', 'E2F5', 'E2F1', 'RELA', 'MAFK'], dtype=object)

# %%
network_file = 'immune_cell.tsv'

N = dNetwork.display_network(network_file, show = False, size_limit=2000)
N.threshhold_slider.value = 19
N.connected_only_click(None)
N.font_size_slider.value = 0
N.tf_font_size_slider.value = 18
N.layout_dropdown.value = 'kamada_kawai'
N.expand_click(None)
N.expand_click(None)
N.labels_button.value = True
N.layout_click(None)
N.title_html.value = 'immune system communication'
N.show()
# Out:
# ('Reading network', 'immune_cell.tsv')
# ('Loading saved layout', 'immune_cell.tsv.layout.json')
# Omitting edges, using canvas, and fast layout default because the network is large

# %% [markdown]
# ## Find Regulators involved in UPR

# %%
GOterm_df = pd.concat(GOterm_dict.values())
GOterm_df = GOterm_df.loc[GOterm_df['NS'] == 'BP',:]
GOterm_df = GOterm_df.loc[GOterm_df['FDR'] <= 0.01,:]

GOterms = sum([[name for name in GOterm_df['name'] if 'unfold' in name],
               [name for name in GOterm_df['name'] if 'ER lumen' in name],
               [name for name in GOterm_df['name'] if 'ERAD' in name],
               [name for name in GOterm_df['name'] if 'endoplasmic reticulum' in name]], [])

UPR_df = GOterm_df.loc[GOterm_df['name'].isin(GOterms),:]

regulators = UPR_df['regulator'].unique()
targets = list(set(sum([genes.split(',') for genes in UPR_df['genes']], [])))
#df = network.loc[network['regulator'].isin(regulators) & network['target'].isin(targets),:]
df = network.loc[network['regulator'].isin(regulators),:]
df.loc[:,'bootstraps'] = df['bootstraps'].astype(str)
df.to_csv('UPR_network.tsv', sep = '\t', index = False, encoding = 'utf-8')

# %%
UPR_df.sort_values('FDR')['regulator'].unique()
# Out:
# array(['ATF6', 'XBP1', 'CREB3'], dtype=object)

# %%
network_file = 'UPR_network.tsv'

N = dNetwork.display_network(network_file, show = False, size_limit=150)
N.threshhold_slider.value = 19
N.font_size_slider.value = 0
N.tf_font_size_slider.value = 15
N.layout_dropdown.value = 'kamada_kawai'
N.expand_click(None)
N.labels_button.value = True
N.layout_click(None)
N.title_html.value = 'UPR'
N.show()
# Out:
# ('Reading network', 'UPR_network.tsv')
# ('Loading saved layout', 'UPR_network.tsv.layout.json')
# Omitting edges, using canvas, and fast layout default because the network is large

# %%
GOterm_df.loc[GOterm_df['regulator'] == 'CREB3',:]
#GOterm_df['regulator'].unique()
# Out:
#   regulator          GO  NS                           name       FDR  \
# 0     CREB3  GO:0006621  BP  protein retention in ER lumen  0.001901
#
#                  genes
# 0  KDELR1,PDIA3,KDELR2

# %%
GOterms = sum([[name for name in GOterm_df['name'] if 'extracellular' in name],
               [name for name in GOterm_df['name'] if '--' in name],
               [name for name in GOterm_df['name'] if '--' in name]], [])
GOterm_df.loc[GOterm_df['name'].isin(GOterms),:].sort_values('FDR')
# Out:
#   regulator          GO  NS                               name           FDR  \
# 2      RFX5  GO:0030198  BP  extracellular matrix organization  6.620626e-08
# 1      PAX2  GO:0030198  BP  extracellular matrix organization  1.109316e-07
# 1      HLTF  GO:0030198  BP  extracellular matrix organization  1.177877e-07
# 0     SIRT1  GO:0030198  BP  extracellular matrix organization  1.527788e-07
# 0    ZBTB7A  GO:0030198  BP  extracellular matrix organization  7.147427e-06
# 1     SMAD3  GO:0030198  BP  extracellular matrix organization  3.271949e-05
# 1     EPAS1  GO:0030198  BP  extracellular matrix organization  4.996169e-05
# 3      HLTF  GO:0022617  BP   extracellular matrix disassembly  2.088763e-04
# 1     HOXD3  GO:0030198  BP  extracellular matrix organization  6.839817e-04
#
#                                                genes
# 2  COL3A1,NID1,VCAN,POSTN,COL5A1,COL5A2,COL6A1,CO...
# 1  COL3A1,LOXL1,VCAN,POSTN,COL5A1,COL5A2,MFAP5,CO...
# 1  COL3A1,SPARC,LAMA4,COL5A1,COL6A1,COL6A2,COL5A3...
# 0  COL3A1,DCN,CRISPLD2,POSTN,COL5A1,COL5A2,NID2,C...
# 0  LOXL1,COL5A1,ITGB5,COL8A1,COL8A2,ADAMTSL2,BGN,...
# 1  HSPG2,CRISPLD2,LOX,LAMB1,COL6A1,COL6A2,COL18A1...
# 1  COL4A1,CYR61,COL5A1,ADAMTSL2,COL14A1,COL7A1,MF...
# 3           MMP14,HTRA1,SH3PXD2B,FBN1,MMP2,ELN,TIMP2
# 1  COL4A1,NID1,ITGAV,THBS1,ITGB1,ITGB3,LAMC1,NID2...

# %%
GOterm_df['name'].unique()
# Out:
# array(['translational initiation',
#        'SRP-dependent cotranslational protein targeting to membrane',
#        'translation', 'viral transcription', 'rRNA processing',
#        'nuclear-transcribed mRNA catabolic process, nonsense-mediated decay',
#        'ribosomal small subunit assembly',
#        'ribosomal large subunit assembly',
#        'ribosomal small subunit biogenesis',
#        'negative regulation of ubiquitin protein ligase activity',
#        'keratinization', 'cornification', 'epidermis development',
#        'regulation of cellular amino acid metabolic process',
#        'negative regulation of G2/M transition of mitotic cell cycle',
#        'NIK/NF-kappaB signaling',
#        'SCF-dependent proteasomal ubiquitin-dependent protein catabolic process',
#        'positive regulation of ubiquitin-protein ligase activity involved in regulation of mitotic cell cycle transition',
#        'negative regulation of ubiquitin-protein ligase activity involved in mitotic cell cycle',
#        'regulation of transcription from RNA polymerase II promoter in response to hypoxia',
#        'anaphase-promoting complex-dependent catabolic process',
#        'antigen processing and presentation of exogenous peptide antigen via MHC class I, TAP-dependent',
#        'mitochondrial translational termination',
#        'mitochondrial translational elongation', 'chromosome segregation',
#        'cell division', 'mitotic sister chromatid segregation',
#        'sister chromatid cohesion', 'microtubule-based movement',
#        'antimicrobial humoral response', 'negative regulation of growth',
#        'cellular response to zinc ion',
#        'positive regulation of telomerase RNA localization to Cajal body',
#        'positive regulation of protein localization to Cajal body',
#        'positive regulation of establishment of protein localization to telomere',
#        'protein stabilization', "'de novo' protein folding",
#        'chaperone-mediated protein complex assembly', 'gene expression',
#        'chaperone-mediated protein folding',
#        'positive regulation of telomere maintenance via telomerase',
#        'cellular detoxification of nitrogen compound',
#        'nitrobenzene metabolic process',
#        'glutathione derivative biosynthetic process',
#        'xenobiotic catabolic process', 'glutathione metabolic process',
#        'transcription, DNA-templated',
#        'regulation of transcription, DNA-templated',
#        'regulation of G1/S transition of mitotic cell cycle',
#        'cell adhesion mediated by integrin',
#        'extracellular matrix organization', 'inflammatory response',
#        'oxygen transport', 'bicarbonate transport',
#        'collagen fibril organization', 'collagen catabolic process',
#        'protein heterotrimerization', 'cell adhesion',
#        'skeletal system development', 'skin development',
#        'cellular response to amino acid stimulus', 'cilium assembly',
#        'intraciliary transport involved in cilium assembly',
#        'cilium movement', 'inner dynein arm assembly',
#        'outer dynein arm assembly',
#        'cardiac muscle cell action potential involved in contraction',
#        'visual perception', 'circadian regulation of gene expression',
#        'DNA unwinding involved in DNA replication', 'DNA replication',
#        'DNA replication initiation', 'NADH oxidation',
#        'mineralocorticoid biosynthetic process',
#        'glucocorticoid biosynthetic process',
#        'androgen biosynthetic process', 'steroid biosynthetic process',
#        'antigen processing and presentation of peptide antigen via MHC class I',
#        'antigen processing and presentation of exogenous peptide antigen via MHC class I, TAP-independent',
#        'interferon-gamma-mediated signaling pathway',
#        'high-density lipoprotein particle remodeling',
#        'cholesterol metabolic process', 'lipoprotein metabolic process',
#        'phospholipid efflux',
#        'low-density lipoprotein particle remodeling',
#        'reverse cholesterol transport',
#        'very-low-density lipoprotein particle clearance',
#        'cholesterol efflux', 'triglyceride metabolic process',
#        'cellular response to transforming growth factor beta stimulus',
#        'negative regulation of JAK-STAT cascade',
#        'adaptive immune response', 'immune response',
#        'regulation of immune response', 'T cell activation',
#        'signal transduction', 'innate immune response',
#        'T cell costimulation',
#        'transmembrane receptor protein tyrosine kinase signaling pathway',
#        'chemokine-mediated signaling pathway',
#        'negative regulation of interferon-gamma production', 'chemotaxis',
#        'T cell receptor signaling pathway', 'T cell chemotaxis',
#        'cellular defense response',
#        'negative regulation of T cell activation',
#        'negative regulation of B cell proliferation',
#        'cell-cell signaling',
#        'positive regulation of T cell proliferation',
#        'B cell receptor signaling pathway',
#        'positive regulation of cAMP metabolic process',
#        'negative regulation of T cell mediated cytotoxicity',
#        'positive regulation of natural killer cell mediated cytotoxicity',
#        'cell surface receptor signaling pathway',
#        'triglyceride biosynthetic process', 'cholesterol homeostasis',
#        'triglyceride homeostasis', 'retinoid metabolic process',
#        'cellular response to cAMP',
#        'antigen processing and presentation of exogenous peptide antigen via MHC class II',
#        'peptide antigen assembly with MHC class II protein complex',
#        'polysaccharide assembly with MHC class II protein complex',
#        'defense response to virus', 'response to virus',
#        'type I interferon signaling pathway',
#        'negative regulation of viral genome replication',
#        'response to lipopolysaccharide',
#        'antigen processing and presentation of endogenous peptide antigen via MHC class I',
#        'positive regulation of interferon-gamma production',
#        'positive regulation of I-kappaB kinase/NF-kappaB signaling',
#        'cytolysis', 'humoral immune response',
#        'positive regulation of T cell mediated cytotoxicity',
#        'negative thymic T cell selection',
#        'natural killer cell activation',
#        'positive regulation of interleukin-4 production',
#        'apoptotic process',
#        'positive regulation of interleukin-10 production',
#        'defense response', 'G-protein coupled receptor signaling pathway',
#        'positive regulation of T cell differentiation',
#        'cellular response to interferon-gamma',
#        'positive regulation of dendritic cell chemotaxis',
#        'positive regulation of natural killer cell mediated cytotoxicity directed against tumor cell target',
#        'positive regulation of release of sequestered calcium ion into cytosol',
#        'regulation of extrinsic apoptotic signaling pathway via death domain receptors',
#        'T cell mediated immunity', 'response to interferon-beta',
#        'negative regulation of type I interferon production',
#        'extracellular matrix disassembly',
#        'endodermal cell differentiation', 'neutrophil degranulation',
#        'leukocyte migration',
#        'complement receptor mediated signaling pathway',
#        'negative regulation of interleukin-12 secretion',
#        'phospholipase C-activating G-protein coupled receptor signaling pathway',
#        'integrin-mediated signaling pathway',
#        'negative regulation of T cell proliferation',
#        'negative regulation of mast cell degranulation',
#        'T cell proliferation involved in immune response',
#        'lung development', 'ossification',
#        'blood coagulation, fibrin clot formation',
#        'positive regulation of peptide hormone secretion',
#        'plasminogen activation', 'protein polymerization',
#        'positive regulation of heterotypic cell-cell adhesion',
#        'fibrinolysis', 'positive regulation of exocytosis',
#        'cellular protein complex assembly',
#        'negative regulation of endothelial cell apoptotic process',
#        'positive regulation of vasoconstriction',
#        'positive regulation of substrate adhesion-dependent cell spreading',
#        'positive regulation of protein secretion',
#        'negative regulation of extrinsic apoptotic signaling pathway via death domain receptors',
#        'toll-like receptor signaling pathway',
#        'induction of bacterial agglutination', 'platelet aggregation',
#        'response to calcium ion', 'cell-matrix adhesion',
#        'toll-like receptor 4 signaling pathway',
#        'lipopolysaccharide-mediated signaling pathway',
#        'positive regulation of tumor necrosis factor biosynthetic process',
#        'positive regulation of B cell proliferation',
#        'negative regulation of B cell receptor signaling pathway',
#        'apoptotic signaling pathway',
#        'activation of innate immune response',
#        'cellular response to lipopolysaccharide',
#        'defense response to protozoan',
#        'positive regulation of interleukin-17 production',
#        'defense response to bacterium',
#        'negative regulation of interleukin-12 production',
#        'positive regulation of tumor necrosis factor production',
#        'neutrophil chemotaxis',
#        'negative regulation of growth of symbiont in host',
#        'positive regulation of natural killer cell chemotaxis',
#        'monocyte chemotaxis', 'cellular response to interleukin-1',
#        'response to interferon-gamma',
#        'positive regulation of ERK1 and ERK2 cascade',
#        'positive regulation of defense response to virus by host',
#        'negative regulation of interleukin-10 production',
#        'regulation of vasculogenesis', 'umbilical cord morphogenesis',
#        'negative regulation of transcription from RNA polymerase II promoter involved in smooth muscle cell differentiation',
#        'arterial endothelial cell differentiation',
#        'Notch signaling involved in heart development',
#        'dorsal aorta morphogenesis', 'cardiac septum morphogenesis',
#        'pulmonary valve morphogenesis', 'cardiac ventricle morphogenesis',
#        'cardiac epithelial to mesenchymal transition',
#        'heart trabecula formation',
#        'negative regulation of transcription regulatory region DNA binding',
#        'labyrinthine layer blood vessel development',
#        'histone acetylation',
#        'positive regulation of NK T cell proliferation',
#        'myeloid dendritic cell differentiation',
#        'positive regulation of GTPase activity',
#        'intracellular signal transduction',
#        'positive regulation of T-helper 1 type immune response',
#        'positive regulation of T-helper 17 cell lineage commitment',
#        'regulation of gene silencing', 'chromatin silencing',
#        'DNA replication-dependent nucleosome assembly',
#        'nucleosome assembly', 'innate immune response in mucosa',
#        'chromatin organization', 'gene silencing by RNA',
#        'chromatin silencing at rDNA',
#        'positive regulation of gene expression, epigenetic',
#        'blood coagulation', 'cellular protein metabolic process',
#        'antibacterial humoral response', 'telomere organization',
#        'negative regulation of gene expression, epigenetic',
#        'protein heterotetramerization',
#        'negative regulation of megakaryocyte differentiation',
#        'telomere capping', 'defense response to Gram-positive bacterium',
#        'DNA replication-independent nucleosome assembly',
#        'protein ubiquitination', 'DNA-templated transcription, initiation',
#        'CENP-A containing nucleosome assembly',
#        'beta-catenin-TCF complex assembly',
#        'double-strand break repair via nonhomologous end joining',
#        'histone H3-K27 trimethylation', 'nucleosome positioning',
#        'histone H3-K4 trimethylation', 'behavioral response to nicotine',
#        'synaptic transmission, cholinergic',
#        'excitatory postsynaptic potential',
#        'synaptic transmission involved in micturition',
#        'anterior/posterior pattern specification',
#        'embryonic skeletal system morphogenesis', 'cell chemotaxis',
#        'B cell proliferation', 'T cell differentiation',
#        'B cell activation',
#        'positive regulation of interleukin-12 production',
#        'negative regulation of T cell apoptotic process',
#        'positive regulation of B cell differentiation',
#        'positive regulation of T cell chemotaxis',
#        'positive regulation of interferon-gamma secretion',
#        'peptidyl-tyrosine autophosphorylation', 'cell migration',
#        'heterophilic cell-cell adhesion via plasma membrane cell adhesion molecules',
#        'intestinal cholesterol absorption',
#        'cholesterol biosynthetic process',
#        'positive regulation of cellular metabolic process',
#        'long-chain fatty-acyl-CoA biosynthetic process',
#        'oxidation-reduction process', 'isoprenoid biosynthetic process',
#        'lipid metabolic process', 'angiogenesis',
#        'negative regulation of BMP signaling pathway',
#        'keratinocyte differentiation', 'peptide cross-linking',
#        'IRE1-mediated unfolded protein response',
#        'response to endoplasmic reticulum stress',
#        'protein folding in endoplasmic reticulum', 'protein folding',
#        'cell redox homeostasis',
#        'maturation of SSU-rRNA from tricistronic rRNA transcript (SSU-rRNA, 5.8S rRNA, LSU-rRNA)',
#        'ribosomal large subunit biogenesis',
#        'negative regulation of protein neddylation',
#        'regulation of hair cycle',
#        'negative regulation of glucocorticoid receptor signaling pathway',
#        'flavone metabolic process', 'xenobiotic glucuronidation',
#        'flavonoid glucuronidation', 'retinoic acid metabolic process',
#        'cellular glucuronidation',
#        'negative regulation of steroid metabolic process',
#        'protein retention in ER lumen', 'tricarboxylic acid cycle',
#        'G1/S transition of mitotic cell cycle', 'mitotic cytokinesis',
#        'DNA repair', 'regulation of cell cycle',
#        'G2/M transition of mitotic cell cycle',
#        'telomere maintenance via recombination',
#        'mitotic spindle organization',
#        'regulation of ubiquitin-protein ligase activity involved in mitotic cell cycle',
#        'DNA synthesis involved in DNA repair',
#        'mitotic metaphase plate congression',
#        'positive regulation of cytokinesis',
#        'protein localization to kinetochore',
#        'regulation of transcription involved in G1/S transition of mitotic cell cycle',
#        'double-strand break repair via homologous recombination',
#        'metaphase plate congression', 'cell proliferation',
#        'cellular response to DNA damage stimulus',
#        'double-strand break repair', 'cytokinesis',
#        'mitotic chromosome condensation',
#        'regulation of cyclin-dependent protein serine/threonine kinase activity',
#        'DNA damage response, signal transduction by p53 class mediator resulting in cell cycle arrest',
#        'mitotic spindle assembly',
#        'retrograde vesicle-mediated transport, Golgi to ER',
#        'regulation of mitotic metaphase/anaphase transition',
#        'regulation of attachment of spindle microtubules to kinetochore',
#        'mitotic spindle midzone assembly', 'microtubule depolymerization',
#        'regulation of mitotic centrosome separation',
#        'homologous chromosome segregation',
#        'mitotic spindle assembly checkpoint',
#        'regulation of mitotic nuclear division', 'telomere maintenance',
#        'kinetochore assembly',
#        'positive regulation of ubiquitin protein ligase activity',
#        'interstrand cross-link repair', 'strand displacement',
#        'spermatogenesis', 'DNA biosynthetic process',
#        'meiotic sister chromatid cohesion, centromeric',
#        'G-quadruplex DNA unwinding',
#        'cellular response to ionizing radiation', 'centriole replication',
#        'DNA recombination', 'mitotic nuclear envelope disassembly',
#        'regulation of signal transduction by p53 class mediator',
#        'DNA strand elongation involved in DNA replication',
#        'spindle organization', 'meiotic chromosome condensation',
#        'protein sumoylation', 'translesion synthesis',
#        'protein ubiquitination involved in ubiquitin-dependent protein catabolic process',
#        'kinetochore organization', 'mitotic recombination',
#        'meiotic chromosome segregation',
#        'attachment of spindle microtubules to kinetochore',
#        'DNA duplex unwinding', 'mitotic sister chromatid cohesion',
#        'response to ionizing radiation',
#        'attachment of mitotic spindle microtubules to kinetochore',
#        'positive regulation of DNA-directed DNA polymerase activity',
#        'mitotic cell cycle checkpoint',
#        'regulation of chromosome segregation',
#        'error-prone translesion synthesis', 'G2 DNA damage checkpoint',
#        'cellular response to UV',
#        'regulation of G2/M transition of mitotic cell cycle',
#        'reciprocal meiotic recombination', 'histone phosphorylation',
#        'ciliary basal body docking',
#        'DNA damage response, detection of DNA damage',
#        'nucleotide-excision repair, DNA gap filling',
#        'cellular response to hydroxyurea',
#        'telomere maintenance via telomere lengthening',
#        'mitotic centrosome separation',
#        'cellular response to hormone stimulus', 'response to cAMP',
#        'positive regulation of transcription from RNA polymerase II promoter',
#        'cellular response to calcium ion', 'response to cytokine',
#        'response to mechanical stimulus', 'response to radiation',
#        'regulation of cell death', 'response to drug',
#        'positive regulation of tyrosine phosphorylation of Stat3 protein',
#        'transcription from RNA polymerase II promoter',
#        'positive regulation of cell differentiation',
#        'response to light stimulus',
#        'skeletal muscle cell differentiation', 'learning',
#        'mitochondrial respiratory chain complex I assembly',
#        'mitochondrial electron transport, NADH to ubiquinone',
#        'protein N-linked glycosylation via asparagine',
#        'ER to Golgi vesicle-mediated transport',
#        'ubiquitin-dependent ERAD pathway'], dtype=object)

# %%
# Not really working... COLORIZING
def network_config(N, gene_list_file, title, threshhold):
    N.threshhold_slider.value = threshhold
    N.apply_click(None)
    geneIn = open(gene_list_file)
    gene_list = []
    for gene in geneIn:
        gene_list.append(gene.strip('\n').lower())
    geneIn.close()
    N.pattern_text.value = ' '.join(gene_list)
    N.match_click(None)
    N.targeted_click(None)
    #N.expand_click(None)
    N5.tf_only_click()
    N.connected_only_click(None)
    N.layout_dropdown.value = 'kamada_kawai'
    #N.layout_dropdown.value = 'fruchterman_reingold'
    N.layout_click(None)
    N.labels_button.value = True
    N.labels_click(None)
    N.title_html.value = title
    
    # color nodes:
    gene_colors = {}
    
    files = [('basal_A.txt', 0),
             ('basal_B.txt', 5),
             ('Her2.txt', 2),
             ('non-Her2.txt', 4)]
    
    for filename, idx in files:
        geneIn = open(filename)
        for gene in geneIn:
            gene = gene.strip('\n')
            gene_colors[gene] = idx
        geneIn.close()

    node_colors = N.display_graph.node_weights
    
    for key in node_colors.keys():
        if key in gene_colors:
            node_colors[key] = gene_colors[key]
        else:
            node_colors[key] = 9
    dNetwork.set_node_color_levels(N)
    
    return(N)

#N5 = dNetwork.display_network('network_breast_cancer_Marcotte2016_BBSR1.1_combinedPriors_TfsPriors.tsv', show = False)
#N5 = network_config(N5, 'genes_subtypes_all.txt', '', 11)
