# %%
import encrypt_files
encrypt_files.decrypt_widget()
# Out:
# click
# extracting password...
# [2, [['method', ['method', ['window'], 'jQuery', '#pw000'], 'val']], 1]
# ... password extracted
# decrypting basal_A.txt.crypt to basal_A.txt
# wrote basal_A.txt
# decrypting basal_B.txt.crypt to basal_B.txt
# wrote basal_B.txt
# decrypting Basal_DE_FCgreater1.tsv.crypt to Basal_DE_FCgreater1.tsv
# wrote Basal_DE_FCgreater1.tsv
# decrypting BRCA.1218_pam50.FINAL.txt.crypt to BRCA.1218_pam50.FINAL.txt
# wrote BRCA.1218_pam50.FINAL.txt
# decrypting expression.tsv.crypt to expression.tsv
# wrote expression.tsv
# decrypting tfa.pyc.crypt to tfa.pyc
# Existing file matches tfa.pyc
# decrypting TNBC_tfsPrior.tsv.crypt to TNBC_tfsPrior.tsv
# wrote TNBC_tfsPrior.tsv
# decrypting TNBC_tfsPrior.tsv.layout.json.crypt to TNBC_tfsPrior.tsv.layout.json
# wrote TNBC_tfsPrior.tsv.layout.json
